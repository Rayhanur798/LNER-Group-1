# %%
import pandas as pd

# %%
fleet_peformance = pd.read_excel("/content/20260213_Fleet_Performance.xlsx")
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# 3407 instances (rows) , 45 features (columns)

# %%
fleet_peformance.shape
# Out:
# (3407, 45)

# %%
fleet_peformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3407 entries, 0 to 3406
# Data columns (total 45 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Row Status                                           3407 non-null   object
#  1   Period                                               3407 non-null   int64
#  2   Incident Number                                      3407 non-null   object
#  3   Incident Date                                        3407 non-null   datetime64[ns]
#  4   Headcode                                             1647 non-null   object
#  5   Train                                                3084 non-null   object
#  6   Incident Location                                    3339 non-null   object
#  7   TARA Primary Delay Minutes                           2737 non-null   float64
# ...

# %%
fleet_peformance.head()
# Out:
#                          Row Status  Period Incident Number Incident Date  \
# 0                               New    2612          192749    2026-02-12
# 1                               New    2612          192000    2026-02-12
# 2                               New    2612          191778    2026-02-12
# 3                               New    2612          191716    2026-02-12
# 4  Root Cause, Bugle Dispute Status    2612          190994    2026-02-11
#
#   Headcode                                              Train  \
# 0     1E15                         09:52 ABERDEEN  to KINGS X
# 1     5S08                         06:34 FERMEPARK to KINGS X
# 2     5A02                                                NaN
# 3     3Y03  04:35 DONCARIEP to YORK\nRunning as 04:57 DONC...
# 4     1D26                         18:03 KINGS X   to SKIPTON
#
#   Incident Location  TARA Primary Delay Minutes  TARA Canx  Primary Mins Sum  \
# ...

# %%
fleet_peformance.isnull().sum()
# Out:
# Row Status                                                0
# Period                                                    0
# Incident Number                                           0
# Incident Date                                             0
# Headcode                                               1760
# Train                                                   323
# Incident Location                                        68
# TARA Primary Delay Minutes                              670
# TARA Canx                                               671
# Primary Mins Sum                                         34
# Total Mins                                                0
# Sum Canx                                                 20
# Equipment Bugle                                          29
# Vehicle No.                                            2173
# Unit No.                                                 22
# Coupled Unit No.                                       3035
# ...

# %% [markdown]
# These variables have 0–2% missing, which is excellent: Incident Date, Total Mins, Period, Incident Number,  Incident Location, Primary Mins Sum ,Train Type ,Sum Canx
#
# These are reliable and suitable for analysis.

# %%
fleet_peformance.isna().sum()/len(fleet_peformance)*100
# Out:
# Row Status                                               0.000000
# Period                                                   0.000000
# Incident Number                                          0.000000
# Incident Date                                            0.000000
# Headcode                                                51.658350
# Train                                                    9.480481
# Incident Location                                        1.995891
# TARA Primary Delay Minutes                              19.665395
# TARA Canx                                               19.694746
# Primary Mins Sum                                         0.997945
# Total Mins                                               0.000000
# Sum Canx                                                 0.587027
# Equipment Bugle                                          0.851189
# Vehicle No.                                             63.780452
# ...

# %%
# columns potentially  to use

#time variables - Incdient date, period

#Delay impact (Important) - Total Mins, Primary Mins Sum, TARA Primary Delay Minutes

#Cancellation indicator - Sum Canx, TARA Canx

#Location context - Incident Location

#Train information - Train Type, Unit No.

#cause/engineering info - Inc Cause, Root Cause, Cause Code, System, Subsystem, Failure

# %%
#we need smth to predict or detect risk:

#eg. Predict high delay incidents: High Delay = Total Mins > 30, Predict Cancellation risk, Predict availability pressure perios - based on: total delay mins, incident frequency, cause types.

# %%
Fleet_delay = pd.read_excel("/content/Fleet Dealy Data from P2301 to P2611.xlsx")

# %% [markdown]
# 3925 instances (rows), 55 features (columns)

# %%
Fleet_delay.shape
# Out:
# (3925, 55)

# %%
Fleet_delay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3925 entries, 0 to 3924
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Inc.#                 3925 non-null   int64
#  1   Date                  3925 non-null   datetime64[ns]
#  2   Status                3925 non-null   object
#  3   Bugle Mgr             3925 non-null   object
#  4   Bugle Mgr Title       3925 non-null   object
#  5   Trust Mgr             3925 non-null   object
#  6   NR Mgr                3925 non-null   object
#  7   Cause                 3925 non-null   object
#  8   Root Cause            3792 non-null   object
#  9   Root Cause Descrip.   3925 non-null   object
#  10  Incid. Location       3918 non-null   object
#  11  Comment               3925 non-null   object
#  12  Equip.                3924 non-null   object
#  13  Tot. Mins             3925 non-null   float64
# ...

# %%
Fleet_delay.head()
# Out:
#           Inc.#       Date Status Bugle Mgr              Bugle Mgr Title  \
# 0  480134220401 2022-04-01      A      MHB2          HITACHI - CLASS 801
# 1  485541220403 2022-04-03      A      MHBK          YARD - CRAIGENTINNY
# 2  485877220403 2022-04-03      A      MHB1          HITACHI - CLASS 800
# 3  487346220404 2022-04-04      A      MHB1          HITACHI - CLASS 800
# 4  488234220404 2022-04-04      A      MHBA  FLEET - CLASS 91 LOCOMOTIVE
#
#   Trust Mgr NR Mgr Cause Root Cause     Root Cause Descrip.  ... Region.  \
# 0      MHB2   OQIE    MN        NaN   No Root Cause entered  ...   Azuma
# 1      MHBK   OQL9    MU        NaN   No Root Cause entered  ...   Depot
# 2      MHB1   OQI8    MY       MY05  Class 800/801 Couplers  ...   Azuma
# 3      MHB1   OQI8    M7       M703          PASSENGER DOOR  ...   Azuma
# 4      MHBA   OQIJ    MB        NaN   No Root Cause entered  ...   IC225
#
#                  Sect2      Day 8  NR KPI  TOC1  TOC2  Region  Funct.  \
# ...

# %%
Fleet_delay.isnull().sum()
# Out:
# Inc.#                      0
# Date                       0
# Status                     0
# Bugle Mgr                  0
# Bugle Mgr Title            0
# Trust Mgr                  0
# NR Mgr                     0
# Cause                      0
# Root Cause               133
# Root Cause Descrip.        0
# Incid. Location            7
# Comment                    0
# Equip.                     1
# Tot. Mins                  0
# Inc. Mins Delay Mins       0
# Delay Mins                 0
# Capes                      0
# Pines                      0
# Calvs                      0
# FTS                        0
# Trains Affect              0
# EQ Mins                    0
# Mgrs Note                  0
# KPI                        0
# Bugle Status               0
# RSP Week                   0
# Inc. Pd                    0
# DfT Full                   0
# DfT Part                   0
# CaSL                       0
# PPM Fail                   0
# Incid. #                   0
# ...

# %%
Fleet_delay.isna().sum()/len(Fleet_delay)*100
# Out:
# Inc.#                     0.000000
# Date                      0.000000
# Status                    0.000000
# Bugle Mgr                 0.000000
# Bugle Mgr Title           0.000000
# Trust Mgr                 0.000000
# NR Mgr                    0.000000
# Cause                     0.000000
# Root Cause                3.388535
# Root Cause Descrip.       0.000000
# Incid. Location           0.178344
# Comment                   0.000000
# Equip.                    0.025478
# Tot. Mins                 0.000000
# Inc. Mins Delay Mins      0.000000
# Delay Mins                0.000000
# Capes                     0.000000
# Pines                     0.000000
# Calvs                     0.000000
# FTS                       0.000000
# Trains Affect             0.000000
# EQ Mins                   0.000000
# Mgrs Note                 0.000000
# KPI                       0.000000
# Bugle Status              0.000000
# RSP Week                  0.000000
# Inc. Pd                   0.000000
# ...

# %%
Fleet_planning = pd.read_excel("/content/Fleet Planning Log.xlsx")

# %%
Fleet_planning.shape
# Out:
# (52, 55)

# %%
Fleet_planning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 55 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FPPM Balance Score Card 2022 / 2023  12 non-null     object
#  1   Unnamed: 1                           35 non-null     object
#  2   Period 1                             36 non-null     object
#  3   Unnamed: 3                           38 non-null     object
#  4   Unnamed: 4                           38 non-null     object
#  5   Unnamed: 5                           38 non-null     object
#  6   Period 2                             40 non-null     object
#  7   Unnamed: 7                           38 non-null     object
#  8   Unnamed: 8                           38 non-null     object
#  9   Unnamed: 9                           38 non-null     object
#  10  Period 3                             38 non-null     object
# ...

# %%
Fleet_planning.head()
# Out:
#   FPPM Balance Score Card 2022 / 2023                Unnamed: 1  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                  Fleet Availability                       NaN
# 3                                 NaN                       NaN
# 4                               800/1  Number of Units Required
#
#               Period 1           Unnamed: 3           Unnamed: 4  \
# 0               Week 1               Week 2               Week 3
# 1  2022-04-01 00:00:00  2022-04-10 00:00:00  2022-04-17 00:00:00
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                   90                   70                   70
#
#             Unnamed: 5             Period 2           Unnamed: 7  \
# 0               Week 4               Week 1               Week 2
# ...

# %%
Fleet_planning.isnull().sum()
# Out:
# FPPM Balance Score Card 2022 / 2023    40
# Unnamed: 1                             17
# Period 1                               16
# Unnamed: 3                             14
# Unnamed: 4                             14
# Unnamed: 5                             14
# Period 2                               12
# Unnamed: 7                             14
# Unnamed: 8                             14
# Unnamed: 9                             14
# Period 3                               14
# Unnamed: 11                            14
# Unnamed: 12                            14
# Unnamed: 13                            14
# Period 4                               14
# Unnamed: 15                            14
# Unnamed: 16                            14
# Unnamed: 17                            14
# Period 5                               14
# Unnamed: 19                            14
# Unnamed: 20                            14
# Unnamed: 21                            14
# ...

# %%
Fleet_planning.isna().sum()/len(Fleet_planning)*100
# Out:
# FPPM Balance Score Card 2022 / 2023    76.923077
# Unnamed: 1                             32.692308
# Period 1                               30.769231
# Unnamed: 3                             26.923077
# Unnamed: 4                             26.923077
# Unnamed: 5                             26.923077
# Period 2                               23.076923
# Unnamed: 7                             26.923077
# Unnamed: 8                             26.923077
# Unnamed: 9                             26.923077
# Period 3                               26.923077
# Unnamed: 11                            26.923077
# Unnamed: 12                            26.923077
# Unnamed: 13                            26.923077
# Period 4                               26.923077
# Unnamed: 15                            26.923077
# Unnamed: 16                            26.923077
# Unnamed: 17                            26.923077
# Period 5                               26.923077
# ...
